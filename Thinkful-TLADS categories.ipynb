# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_style('white')

# %%
df = pd.read_csv('ESSdata_Thinkful.csv')

print(df)
# Out:
#      cntry    idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  \
# 0       CH     5.0     6    3.0      3.0     10.0     5.0    8.0      5.0
# 1       CH    25.0     6    6.0      5.0      7.0     5.0    9.0      3.0
# 2       CH    26.0     6    1.0      8.0      8.0     8.0    7.0      6.0
# 3       CH    28.0     6    4.0      6.0      6.0     7.0   10.0      6.0
# 4       CH    29.0     6    5.0      6.0      7.0     5.0    8.0      7.0
# 5       CH    36.0     6    4.0      6.0      7.0     3.0    8.0      7.0
# 6       CH    40.0     6    3.0      0.0      5.0     2.0    0.0      2.0
# 7       CH    41.0     6    2.0      4.0      5.0     3.0   10.0      5.0
# 8       CH    51.0     6    2.0      8.0      8.0     8.0    9.0      6.0
# 9       CH    53.0     6    4.0      4.0      4.0     8.0    7.0      4.0
# 10      CH    55.0     6    1.0      6.0      7.0     7.0    9.0      5.0
# 11      CH    56.0     6    4.0      5.0      7.0     7.0    7.0      5.0
# ...

# %% [markdown]
# ## The 'cntry' variable is categorical

# %%
df.groupby('cntry').describe()
# Out:
#          agea                                                         gndr  \
#         count       mean        std   min   25%   50%   75%    max   count
# cntry
# CH     1503.0  46.743180  18.632669  16.0  32.0  46.0  61.0   94.0  1546.0
# CZ     1280.0  46.301563  16.888995  15.0  34.0  46.0  59.0   91.0  1306.0
# DE       28.0  55.892857  16.067771  26.0  49.0  55.5  65.5   89.0    28.0
# ES     2360.0  47.874576  18.200719  16.0  34.0  47.0  61.0  103.0  2426.0
# NO     1436.0  46.536212  18.203938  15.0  32.0  46.0  60.0   94.0  1462.0
# SE     1748.0  49.040046  19.536782  15.0  32.0  50.0  65.0  114.0  1816.0
#
#                 ...  tvtot         year                                     \
#            mean ...    75%  max   count mean       std  min  25%  50%  75%
# cntry           ...
# CH     1.513583 ...    4.0  7.0  1546.0  6.5  0.500162  6.0  6.0  6.5  7.0
# CZ     1.525268 ...    7.0  7.0  1316.0  6.5  0.500190  6.0  6.0  6.5  7.0
# ...

# %% [markdown]
# ## 'idno' is a continuous variable. Id number

# %%
df.groupby('idno').describe().head(20)
# Out:
#       agea                                                    gndr      ...   \
#      count   mean        std   min    25%   50%    75%   max count mean ...
# idno                                                                    ...
# 1.0    2.0  52.00  25.455844  34.0  43.00  52.0  61.00  70.0   2.0  2.0 ...
# 3.0    2.0  56.50   3.535534  54.0  55.25  56.5  57.75  59.0   2.0  1.5 ...
# 5.0    4.0  53.25  13.889444  38.0  44.00  53.0  62.25  69.0   4.0  1.5 ...
# 6.0    2.0  51.00  22.627417  35.0  43.00  51.0  59.00  67.0   2.0  2.0 ...
# 7.0    2.0  95.50   0.707107  95.0  95.25  95.5  95.75  96.0   2.0  2.0 ...
# 8.0    2.0  53.50  10.606602  46.0  49.75  53.5  57.25  61.0   2.0  2.0 ...
# 10.0   2.0  49.50  16.263456  38.0  43.75  49.5  55.25  61.0   2.0  1.5 ...
# 13.0   2.0  93.00   1.414214  92.0  92.50  93.0  93.50  94.0   2.0  1.5 ...
# 15.0   2.0  53.50   2.121320  52.0  52.75  53.5  54.25  55.0   2.0  1.5 ...
# ...

# %% [markdown]
# ## Year is a categorical variable

# %%
df.groupby('year').describe().head(20)
# Out:
#         agea                                                         gndr  \
#        count       mean        std   min   25%   50%   75%    max   count
# year
# 6     4171.0  47.524814  18.196188  15.0  33.0  47.0  62.0  103.0  4297.0
# 7     4184.0  47.416826  18.597779  15.0  33.0  47.0  62.0  114.0  4287.0
#
#                ...  sclmeet        tvtot                                     \
#           mean ...      75%  max   count      mean       std  min  25%  50%
# year           ...
# 6     1.498720 ...      6.0  7.0  4291.0  3.923095  2.016634  0.0  2.0  4.0
# 7     1.495685 ...      6.0  7.0  4295.0  3.800931  2.021127  0.0  2.0  4.0
#
#
#       75%  max
# year
# 6     6.0  7.0
# 7     5.0  7.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ## 'tvtot' is a categorical variable or interval. It is the time spent watching TV.

# %%
df.groupby('tvtot').describe().head(20)
# Out:
#          agea                                                          gndr  \
#         count       mean        std   min   25%   50%    75%    max   count
# tvtot
# 0.0     370.0  39.700000  16.664854  15.0  26.0  37.0  50.00   97.0   372.0
# 1.0     682.0  40.263930  16.234628  15.0  27.0  40.0  51.00  114.0   691.0
# 2.0    1415.0  43.442403  16.813795  15.0  30.0  43.0  55.00   94.0  1435.0
# 3.0    1363.0  45.431401  18.004371  15.0  32.0  45.0  59.00  101.0  1392.0
# 4.0    1370.0  47.413139  17.328775  15.0  34.0  48.0  60.75   93.0  1404.0
# 5.0    1165.0  49.614592  18.401030  15.0  35.0  50.0  63.00   93.0  1215.0
# 6.0     775.0  51.797419  18.363442  16.0  38.0  54.0  67.00   93.0   803.0
# 7.0    1207.0  56.212925  19.044991  15.0  42.0  60.0  71.00  103.0  1264.0
#
#                 ...  sclmeet         year                                     \
#            mean ...      75%  max   count      mean       std  min  25%  50%
# tvtot           ...
# ...

# %% [markdown]
# ## 'ppltrst' is a categorical variable or ratio. Mostly people trust or can't be trusted?

# %%
df.groupby('ppltrst').describe().head(20)
# Out:
#            agea                                                         \
#           count       mean        std   min    25%   50%    75%    max
# ppltrst
# 0.0       257.0  53.420233  18.996157  16.0  37.00  54.0  69.00   95.0
# 1.0       163.0  49.638037  17.703254  16.0  34.00  51.0  63.50   90.0
# 2.0       424.0  49.570755  18.728613  16.0  35.75  48.0  64.00   97.0
# 3.0       700.0  48.231429  17.872802  15.0  34.00  49.0  62.00   90.0
# 4.0       751.0  45.902796  18.950810  15.0  31.00  45.0  60.00   93.0
# 5.0      1646.0  47.443499  18.556973  15.0  33.00  47.0  61.00  103.0
# 6.0      1071.0  46.068161  19.036022  15.0  30.00  45.0  61.00   94.0
# 7.0      1598.0  45.932416  17.661797  15.0  32.00  46.0  60.00  101.0
# 8.0      1267.0  48.429361  17.958096  15.0  35.00  48.0  62.00  114.0
# 9.0       326.0  47.180982  18.057883  16.0  34.00  47.0  61.00   89.0
# 10.0      138.0  52.246377  18.027073  16.0  39.25  51.5  67.75   92.0
#
# ...

# %% [markdown]
# ## 'pplfair'  is a categorical variable or ratio. Mostly fair or advantageous

# %%
df.groupby('pplfair').describe().head(20)
# Out:
#            agea                                                         \
#           count       mean        std   min    25%   50%    75%    max
# pplfair
# 0.0       160.0  51.143750  17.832148  16.0  37.00  51.0  64.00   91.0
# 1.0       108.0  46.379630  19.989585  16.0  28.75  43.5  62.25   90.0
# 2.0       293.0  50.187713  18.407179  16.0  37.00  50.0  63.00   97.0
# 3.0       555.0  48.630631  17.379564  16.0  35.00  49.0  62.00   90.0
# 4.0       606.0  46.727723  18.169909  15.0  33.00  46.0  60.00   94.0
# 5.0      1564.0  46.295396  18.422488  15.0  32.00  45.0  61.00   95.0
# 6.0      1016.0  45.477362  18.142009  15.0  31.00  45.0  59.00  114.0
# 7.0      1780.0  46.246629  17.764190  15.0  32.00  46.0  59.00  103.0
# 8.0      1578.0  49.087452  18.372320  15.0  35.00  49.0  63.00   94.0
# 9.0       453.0  47.101545  19.461292  15.0  31.00  47.0  62.00   91.0
# 10.0      205.0  56.590244  19.431072  15.0  44.00  58.0  71.00   93.0
#
# ...

# %% [markdown]
# ## 'pplhlp' is a categorical variable or ratio. Mostly helping or looking out for themselves

# %%
df.groupby('pplhlp').describe().head(20)
# Out:
#           agea                                                          gndr  \
#          count       mean        std   min    25%   50%   75%    max   count
# pplhlp
# 0.0      214.0  50.004673  18.729981  16.0  36.00  49.0  62.0   90.0   221.0
# 1.0      185.0  47.032432  17.375615  16.0  34.00  45.0  60.0   90.0   189.0
# 2.0      470.0  47.463830  17.483522  15.0  34.00  45.5  61.0   93.0   485.0
# 3.0      921.0  46.409338  17.335772  15.0  32.00  46.0  59.0   97.0   939.0
# 4.0      899.0  44.706340  18.233284  15.0  30.00  44.0  58.0   94.0   915.0
# 5.0     1712.0  48.634930  18.764417  15.0  34.00  49.0  63.0  114.0  1760.0
# 6.0     1182.0  45.558376  17.951281  15.0  31.00  45.0  59.0  101.0  1222.0
# 7.0     1390.0  46.551079  18.017228  15.0  32.25  47.0  60.0   95.0  1425.0
# 8.0      948.0  50.697257  18.769600  15.0  36.00  51.0  65.0   94.0   976.0
# 9.0      282.0  50.127660  19.755931  15.0  36.00  49.0  66.5   93.0   292.0
# ...

# %% [markdown]
# ## Happy is a categorical variable or ratio. How happy are you?

# %%
df.groupby('happy').describe().head(20)
# Out:
#          agea                                                          gndr  \
#         count       mean        std   min    25%   50%   75%    max   count
# happy
# 0.0      27.0  57.518519  17.859215  25.0  45.00  52.0  73.5   85.0    29.0
# 1.0      22.0  51.500000  19.444059  17.0  39.25  53.5  63.5   83.0    22.0
# 2.0      55.0  51.127273  19.886767  17.0  35.00  52.0  67.5   90.0    57.0
# 3.0     121.0  50.008264  18.888046  18.0  37.00  48.0  62.0   91.0   124.0
# 4.0     171.0  49.894737  16.650050  16.0  37.50  49.0  61.5   89.0   174.0
# 5.0     584.0  50.681507  17.614354  16.0  37.75  51.0  63.0   96.0   606.0
# 6.0     594.0  48.755892  18.161706  16.0  35.00  48.0  62.0   97.0   612.0
# 7.0    1487.0  46.178211  17.567324  15.0  33.00  46.0  58.0  101.0  1523.0
# 8.0    2475.0  47.083636  18.041895  15.0  33.00  47.0  61.0   95.0  2536.0
# 9.0    1691.0  46.033708  18.625571  15.0  31.00  46.0  61.0   95.0  1737.0
# ...

# %% [markdown]
# ## 'sclmeet' is a categorical variable or interval. How often do you meet with friends?

# %%
df.groupby('sclmeet').describe().head(20)
# Out:
#            agea                                                         gndr  \
#           count       mean        std   min   25%   50%   75%    max   count
# sclmeet
# 1.0        87.0  56.057471  19.918646  16.0  41.0  57.0  73.0   90.0    99.0
# 2.0       380.0  53.144737  15.989858  16.0  41.0  52.5  64.0   90.0   398.0
# 3.0       581.0  52.268503  15.822186  15.0  42.0  51.0  63.0   92.0   602.0
# 4.0      1555.0  51.136334  16.819373  15.0  39.0  51.0  64.0   95.0  1593.0
# 5.0      1429.0  49.386284  17.200595  15.0  36.0  50.0  62.0   97.0  1472.0
# 6.0      2694.0  45.311433  18.698933  15.0  30.0  44.0  60.0  101.0  2757.0
# 7.0      1614.0  42.281289  19.748862  15.0  24.0  41.0  57.0  114.0  1648.0
#
#                   ...  tvtot         year                                     \
#              mean ...    75%  max   count      mean       std  min  25%  50%
# sclmeet           ...
# 1.0      1.505051 ...    7.0  7.0   100.0  6.470000  0.501614  6.0  6.0  6.0
# ...

# %% [markdown]
# ## 'sclact' is a categorical variable or ordinal. Social activities compared to others in age group.

# %%
df.groupby('sclact').describe().head(20)
# Out:
#           agea                                                          gndr  \
#          count       mean        std   min    25%   50%   75%    max   count
# sclact
# 1.0      763.0  52.562254  19.173397  16.0  38.00  52.0  68.0  103.0   800.0
# 2.0     2145.0  48.093706  17.714440  15.0  35.00  48.0  61.0  114.0  2193.0
# 3.0     3971.0  45.817175  18.019282  15.0  31.00  45.0  60.0  101.0  4060.0
# 4.0     1171.0  47.428693  19.274065  15.0  31.00  48.0  63.0   95.0  1213.0
# 5.0      220.0  49.590909  19.673961  16.0  33.75  51.0  65.0   92.0   224.0
#
#                  ...  tvtot         year                                     \
#             mean ...    75%  max   count      mean       std  min  25%  50%
# sclact           ...
# 1.0     1.571250 ...    7.0  7.0   800.0  6.476250  0.499748  6.0  6.0  6.0
# 2.0     1.478796 ...    6.0  7.0  2195.0  6.498861  0.500113  6.0  6.0  6.0
# 3.0     1.507635 ...    5.0  7.0  4068.0  6.504425  0.500042  6.0  6.0  7.0
# ...

# %% [markdown]
# ## 'gndr is a categorical variable

# %%
df.groupby('gndr').describe().head(20)
# Out:
#         agea                                                        happy  \
#        count       mean        std   min   25%   50%   75%    max   count
# gndr
# 1.0   4191.0  46.973037  18.222399  15.0  33.0  46.0  61.0  114.0  4304.0
# 2.0   4154.0  47.922966  18.545597  15.0  33.0  48.0  62.0  101.0  4249.0
#
#                ...  tvtot         year                                     \
#           mean ...    75%  max   count      mean       std  min  25%  50%
# gndr           ...
# 1.0   7.729786 ...    5.0  7.0  4316.0  6.500927  0.500057  6.0  6.0  7.0
# 2.0   7.660391 ...    5.0  7.0  4268.0  6.497891  0.500054  6.0  6.0  6.0
#
#
#       75%  max
# gndr
# 1.0   7.0  7.0
# 2.0   7.0  7.0
#
# [2 rows x 88 columns]

# %% [markdown]
# ## 'agea' is a continious variable but it could also be a ratio. It is the age.

# %%
df.groupby('agea').describe().head(20)
# Out:
#        gndr                                               happy            \
#       count      mean       std  min  25%  50%  75%  max  count      mean
# agea
# 15.0   23.0  1.347826  0.486985  1.0  1.0  1.0  2.0  2.0   23.0  8.652174
# 16.0  122.0  1.426230  0.496567  1.0  1.0  1.0  2.0  2.0  122.0  8.098361
# 17.0  143.0  1.566434  0.497309  1.0  1.0  2.0  2.0  2.0  143.0  8.146853
# 18.0  140.0  1.471429  0.500975  1.0  1.0  1.0  2.0  2.0  139.0  7.992806
# 19.0  128.0  1.507812  0.501903  1.0  1.0  2.0  2.0  2.0  128.0  7.835938
# 20.0  114.0  1.543860  0.500272  1.0  1.0  2.0  2.0  2.0  114.0  7.877193
# 21.0  110.0  1.418182  0.495518  1.0  1.0  1.0  2.0  2.0  110.0  7.845455
# 22.0  132.0  1.462121  0.500462  1.0  1.0  1.0  2.0  2.0  131.0  8.114504
# 23.0  135.0  1.422222  0.495753  1.0  1.0  1.0  2.0  2.0  135.0  7.822222
# 24.0  116.0  1.500000  0.502169  1.0  1.0  1.5  2.0  2.0  116.0  7.931034
# 25.0  114.0  1.473684  0.501511  1.0  1.0  1.0  2.0  2.0  114.0  7.824561
# ...

# %% [markdown]
# ## Partner is a categorical variable

# %%
df.groupby('partner').describe().head(20)
# Out:
#            agea                                                         gndr  \
#           count       mean        std   min   25%   50%   75%    max   count
# partner
# 1.0      5112.0  51.096831  15.003470  18.0  39.0  51.0  62.0   95.0  5276.0
# 2.0      3226.0  41.747985  21.564169  15.0  22.0  37.0  59.0  114.0  3291.0
#
#                   ...  tvtot         year                                     \
#              mean ...    75%  max   count      mean       std  min  25%  50%
# partner           ...
# 1.0      1.480857 ...    5.0  7.0  5276.0  6.493177  0.500001  6.0  6.0  6.0
# 2.0      1.522941 ...    6.0  7.0  3301.0  6.510451  0.499966  6.0  6.0  7.0
#
#
#          75%  max
# partner
# 1.0      7.0  7.0
# 2.0      7.0  7.0
#
# [2 rows x 88 columns]
